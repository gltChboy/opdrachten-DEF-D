# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 2 invul template
#
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in (als in *PR* op GitHub en de link op Brightspace). Zet jullie groepsnummer, studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.
#
# | Groep: XX     |  |
# | :-------------|:-------------|
# | Bart de Jong | 6531598 |
# | Meike Ligtenberg| 6242545 |
# | Erik van den Berg| 6328407 |
# | Planning Groep: XX     |Tijdstip / Tijdspanne  |
# |---|---|
# | condencator bouwen & 3 checks | 12:45 |
# | ontwerp sensor | 14:00 (ideaal 12:45) |
# | sensor bouwen| 14:45 |
# | sensor doormeten & calibreren| 16:00 |
# | data analyse & plotten | 16:45|
# | opgeruimd | 17:15|
# | Pauze 1| 12:30 - 13:30 |
# | Pauze 2| open voor eigen inplanning (15 min) |

# %% [markdown]
# #### Voeg hier een foto van de schets van je plaatcondensator in. Geef daarbij ook duidelijk de waarde van $A$ en $d$ aan.
# <img src="plaatcondensator_schets.jpeg" alt="schets student 1" width="400"/>
#
# L: lengte van de zijdes van de plaat
#
# A: het overlappende oppervlakte van de condensator
#
# d: afstand tussen de platen
#
# $\epsilon_{i}$: permabiliteit van de tussen stof

# %% [markdown]
# ## *Opdracht 1*: Sanity check 3

# %%
import numpy as np
import matplotlib.pyplot as plt

# Schrijf hier een python functie die de capaciteit van een plaatcondensator uitrekent. Zorg dat de functie
# als input de ontwerpparameters van de vlakke plaat formule accepteert (oppervlakte, afstand en diëlektrische
# constante) en als output de capaciteit van de vlakke plaat condensator met die ontwerpparameters.
# Je gaat deze formule de rest van de dag gebruiken: controleer hem goed!
epsilon0 = 8.854187817e-12 # F/m

def vlakkeplaat(A, d, epsilon1 =1):
    # A: oppervlakte van de platen (m²)
    # d: afstand tussen de platen (m)
    # epsilon0: permittiviteit van vacuum (F/m)
    # epsilon1: relatieve permittiviteit van het materiaal tussen de platen (dimensionless)
    # bij vacuum en lucht geld epsilon1 = 1
    global epsilon0
    C = (epsilon0 * epsilon1* A)/ d
    return C

# %%
# Gebruik je formule om uit te rekenen wat je verwacht dat de capaciteit van jullie vlakke plaat condensatoren
# gaat zijn.

C = [vlakkeplaat(2.0, 0.001), vlakkeplaat(4.7, 0.001),vlakkeplaat(1.2, 0.001)]

print(f"Berekende capaciteit plaatcondensator groep 52 is {C[0]:.3e} F")
print(f"Berekende capaciteit plaatcondensator groep 52 is {C[1]:.3e} F")
print(f"Berekende capaciteit plaatcondensator groep 52 is {C[2]:.3e} F")
# Out:
# Berekende capaciteit plaatcondensator groep 52 is 1.771e-08 F
# Berekende capaciteit plaatcondensator groep 52 is 4.161e-08 F
# Berekende capaciteit plaatcondensator groep 52 is 1.063e-08 F

# %% [markdown]
# #### Voeg hier een foto van je plaatcondensator en van de meting op de scope in. Dus 2 foto's.
# ![scope meting 1](opstelling1.jpeg)
# ![scope meting 2](opstelling2.jpeg)

# %%
#berekende
epsilon1 = 2 #permabiliteit van het tussenmatereaal (volgens wikipedia)
A = 0.1**2  #m^2
d = 0.00011    #m

C = vlakkeplaat(A, d, epsilon1)
print(f"Berekende capaciteit plaatcondensator groep 52 is {C:.3e} F")

R_shunt = 1000 #Ohm
f = 100000 #Hz
V_out = C * R_shunt * 2 * np.pi * f
print(f"De output spanning van de sensor is {V_out:.3e} V")

#gemete onderdeel
V_out_gemeten = 4.46#V
print(f"De gemeten output spanning van de sensor is {V_out_gemeten:.3e} V")
C = V_out_gemeten/(R_shunt * 2 * np.pi * f)
print(f"De gemeten capaciteit van de sensor is {C:.3e} F")
# Out:
# Berekende capaciteit plaatcondensator groep 52 is 1.610e-09 F
# De output spanning van de sensor is 1.012e+00 V
# De gemeten output spanning van de sensor is 4.460e+00 V
# De gemeten capaciteit van de sensor is 7.098e-09 F

# %% [markdown]
# ### Meting capaciteit
# Vul onderstaande tabel in. Bij Sanity check 2 heb je afgeleid hoe je van berekende capaciteit naar berekend voltage gaat en terug.
#
#
# | Namen         | Berekende capaciteit   | Berekend Voltage | Gemeten Voltage | Gemeten capaciteit   |
# |-------------|-------------:|-------------:|-------------:|-------------:|
# | groep 52| 1.610e-9 F |1.012 V | 4.460 V|7.098e-09 F |
#
# de rede voor deze grote afwijking kan komen door de volgende dingen:
#
# volgens wikipedia licht $\epsilon_{1}$ tussen 2 en 2.3
# we hebben de dikte van het papier niet exact kunnen bereken maar een gemiddelde van het internet genomen. (zou met 0.02 mm kunnen varieren)
# de draden en meetinstrumenten hebben ook een aparte capaciteit die ook wordt megerekend

# %% [markdown]
# ## *Opdracht 2:* Synthese.
#
# #### Voeg hier voor een foto van je schets(en) van minimaal drie sensoren in.
# ![drie schetsen](sensormogenlijkheden.jpeg)
#
# 1. weegschaal varieert de dikte afhankelijk van de massa die erop geledt is
#
# 2. meet de verplaatsing afhankelijk van het overlappende oppervlakte
#
# 3. bepaling van de stof afhankelijk van de permabiliteit

# %% [markdown]
# ## Opdracht 3: Welke sensor gaan jullie maken?
#
# Wij gaan een sensor maken die kracht meet.
#
# m.a.w
# we gaan de weegschaal maken om afhankelijk van het gewicht de dikte d te varieren en dus de capasiteit van de condensator

# %% [markdown]
# ## Opdracht 4: Uitgewerkte schets (afmetingen!) en plot van de ontwerpgrafiek.
#
# #### Voeg hier een foto van jullie uitgewerkte  schets van de sensor die jullie gaan maken in
# ![uitgewerkte schets](uiteindelijke_schets.jpeg)

# %%
# de dikte van de spons tussen de platen
d1 = 0.01037 #m geen indrukking bij 0 kg
d2 = 0.00067 #m volledig ingedrukt bi 4kg (geschatte massa)

m = np.linspace(0, 4, 100) #kg
#wij verwachten een linear verband tussen de massa en de dikte van de spons
d = d1 - (d1-d2)/max(m) * m

# deze waarde had berekend kunnen worden maar hier was helaas geen tijd voor
# dus hebben wij hem op 1 gelagen (dit was in overleg de TA)
epsilon_matereaal = 1 

C = vlakkeplaat(A, d, epsilon1 = epsilon_matereaal)

#plot
plt.figure(figsize=(8,5))
plt.plot(m, C *1e12, label="Capaciteit van de sensor")

plt.xlabel("Massa op de sensor (kg)")
plt.ylabel("Capaciteit van de sensor (pF)")

plt.grid()
plt.legend()
plt.show()

print(max(C), min(C), np.average(C))
# Out:
# 1.321520569701492e-10 8.538271761812924e-12 2.5474674726545157e-11

# %% [markdown]
# ## Opdracht 5: Invullen tabel LTSpice.
#
# |         | Capaciteit waarde (pF)  | LTSpice berekend output Vpp (mV)|
# |-------------|-------------:|-------------:|
# | minmale capaciteit| 12 |~0 |
# | gemiddelde capaciteit| 25 |0.1 |
# | maximale capaciteit| 185 |1.7 |

# %% [markdown]
# ## Opdracht 6: Foto's werkende opstelling.
#
# #### Voeg hier de foto's van je sensoren in actie in.
# ![meting 1](opdracht6.1.jpeg)
# ![meting 2](opdracht6.2.jpeg)

# %% [markdown]
# ## Opdracht 7: Plot de kalibratiegrafiek.

# %%
from scipy.optimize import curve_fit

m = np.array([0, 0.5145, 0.5981, 0.7202, 0.9348, 1.1196, 1.4345, 1.8805, 2.3896, 3.213]) #kg
F = np.array([51.1, 74.0, 82, 85, 218, 298, 488, 504, 580, 650]) * 1e-12 

def model(m ,a,b,c):
    return a/(b + m * c)

popt, pcov = curve_fit(model, m, F)
print(popt)
#plot
plt.figure(figsize=(8,5))
plt.xlabel("Massa op de sensor (kg)")
plt.ylabel("Capaciteit van de sensor (pF)")
plt.plot(m, F * 1e12, ".", label="gemeten data")
plt.plot(m, model(m, *popt) * 1e12, label="fit")
plt.grid()
plt.errorbar(m, F * 1e12, yerr=10*m, fmt="none")
plt.show()
# Out:
# [ 2.63669673e-08  1.33966812e+02 -3.02662508e+01]

# %% [markdown]
# ![meting 2](rede_voor_fit.jpeg)

# %% [markdown]
# ## Opdracht 8: Vul de tekst aan.
#
# Onze sensor kan nog verbeterd worden door de volgende verbeteringen (minimaal 2):
#
# * Het schuim tussen de platen was niet overal even dik, waardoor een massa, als die op een andere manier werd neergelegd, een ander resultaat opleverde.
# * Het schuim was nat, waardoor er na verdamping een andere permittiviteit verscheen.

# %% [markdown]
# ## Opdracht 9: Uiteindelijke ontwerp en kalibratiegrafiek.
#
# #### Voeg hier een foto van je uiteindelijke sensor in.
# ![foto sensor](uiteindelijke_sensor.jpeg)

# %% [markdown]
# ## Opdracht 10: Vul hieronder de conclusie in.
#
# De sensor is niet geschikt voor het meten van gewichten, want de capaciteit van de sensor verschilde flink per massa, maar het was niet mogelijk om hier een natuurkundig verband uit te extraheren. De grafiek nam namelijk eerst snel toe, waarna hij afnam, terwijl de verwachte grafiek zou moeten zijn. Verder zijn sponzen niet geschikt om te gebruiken als medium om te compresseren. Dit komt doordat de spons een variërende permittiviteit heeft.

# %% [markdown]
# ## Opdracht 11: Kopieer hieronder de leerdoelen.
# 1. Het kunnen gebruiken van de eigenschappen van een elektrische component in een ontwerpproces om een fysische grootheid te meten.
# 2. Kennis hebben van gedrag van elektrische componenten en meetopstellingen.
# 3. Onderdelen van een datasheet zoals een kalibratiegrafiek opstellen, gevoeligheid en onzekerheid beschrijven.

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 1 beheersen.

# %% [markdown]
# ![uitgewerkte schets](uiteindelijke_schets.jpeg)
# ![uitgewerkte schets](ontwerpgrafiek.png)

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 2 beheersen.

# %% [markdown]
# |         | Capaciteit waarde (pF)  | LTSpice berekend output Vpp (mV)|
# |-------------|-------------:|-------------:|
# | minmale capaciteit| 12 |~0 |
# | gemiddelde capaciteit| 25 |0.1 |
# | maximale capaciteit| 185 |1.7 |

# %%
import numpy as np
import matplotlib.pyplot as plt

# Schrijf hier een python functie die de capaciteit van een plaatcondensator uitrekent. Zorg dat de functie
# als input de ontwerpparameters van de vlakke plaat formule accepteert (oppervlakte, afstand en diëlektrische
# constante) en als output de capaciteit van de vlakke plaat condensator met die ontwerpparameters.
# Je gaat deze formule de rest van de dag gebruiken: controleer hem goed!
epsilon0 = 8.854187817e-12 # F/m

def vlakkeplaat(A, d, epsilon1 =1):
    # A: oppervlakte van de platen (m²)
    # d: afstand tussen de platen (m)
    # epsilon0: permittiviteit van vacuum (F/m)
    # epsilon1: relatieve permittiviteit van het materiaal tussen de platen (dimensionless)
    # bij vacuum en lucht geld epsilon1 = 1
    global epsilon0
    C = (epsilon0 * epsilon1* A)/ d
    return C

# %% [markdown]
# <img src="plaatcondensator_schets.jpeg" alt="schets student 1" width="400"/>

# %% [markdown]
# ![meting 1](opdracht6.1.jpeg)
# ![meting 2](opdracht6.2.jpeg)

# %% [markdown]
# kopieer hier de cel(len) waaruit blijkt dat jullie leerdoel 3 beheersen.

# %%
from scipy.optimize import curve_fit

m = np.array([0, 0.5145, 0.5981, 0.7202, 0.9348, 1.1196, 1.4345, 1.8805, 2.3896, 3.213]) #kg
F = np.array([51.1, 74.0, 82, 85, 218, 298, 488, 504, 580, 650]) * 1e-12 

def model(m ,a,b,c):
    return a/(b + m * c)

popt, pcov = curve_fit(model, m, F)
print(popt)
#plot
plt.figure(figsize=(8,5))
plt.xlabel("Massa op de sensor (kg)")
plt.ylabel("Capaciteit van de sensor (pF)")
plt.plot(m, F * 1e12, ".", label="gemeten data")
plt.plot(m, model(m, *popt) * 1e12, label="fit")
plt.grid()
plt.errorbar(m, F * 1e12, yerr=10*m, fmt="none")
plt.show()
# Out:
# [ 2.63669673e-08  1.33966812e+02 -3.02662508e+01]
